# %%
from pandasgui import show

# %% [markdown]
# # IMPORTS

# %%
from IPython.display import HTML, display, clear_output
display(HTML('<style>.container { width:90% !important; }</style>'))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import camelot
from os import listdir
from os.path import isfile, join
import datetime
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
import locale
import re
import uuid
from tqdm.notebook import tqdm, trange
from tqdm import notebook
import numpy as np
from collections import Counter
locale.setlocale(locale.LC_ALL, 'fr_FR.UTF-8');
# Out:
# <style>.container { width:90% !important; }</style>

# %%
statement_dir = "../../application/data/statements"
statements = [f"{statement_dir}/{f}" for f in listdir(statement_dir) if isfile(join(statement_dir, f))]
statements.sort()

# %%
statements

# %%
def check_first(df):

    row = df.loc[0]

    if row[0] == 'Date' and row[1] == 'Libellé' and row[2] == 'Débit' and row[3] == 'Crédit' and row[4] == 'Solde':
        df.drop(0, axis=0, inplace=True)
        df.reset_index(drop=True, inplace=True)

    return df    

def process_statement(statement):   
    
    reader = camelot.read_pdf(statement, pages="all")

    month = pd.DataFrame(dtype=object)

    for i in range(len(reader)):
        df = reader[i].df
        df = check_first(df)
        month = pd.concat([month, df], ignore_index=True)    
    
    return month

def process_statement_dir(statements: list):
    
    assert isinstance(statements, list)
    
    cma_raw = pd.DataFrame(dtype=object)

    for statement in tqdm(statements):
        
        yr_mth = pd.to_datetime(statement[-10:-4], format="%Y%m")
        
        print(f'processing {yr_mth.strftime("%B")} {yr_mth.strftime("%Y")}', end='\t\t\t\t\t\t\t\t\r')
        
        month = process_statement(statement)
        
        cma_raw = pd.concat([cma_raw, month], ignore_index=True)        
        
        # print(f'{yr_mth.strftime("%B")} {yr_mth.strftime("%Y")} processed', end='\n')
        
        # cma_raw["year_mth"] = [f'{yr_mth.strftime("%Y")} {yr_mth.strftime("%m")}' for i in range(cma_raw.shape[0])]
        
    return cma_raw

# %%
cma_raw = process_statement_dir(statements)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# processing janvier 2024

# %%
def process_cma(cma_raw):
    
    cma = cma_raw.copy()
    
    cma.columns = ["date_dt", "object", "debit", "credit", "balance"]

    cma["date_dt"] = pd.to_datetime(cma["date_dt"], format="%d/%m/%Y") 

    cma["credit"] = [float(v) if v != "" else "" for v in cma["credit"] ]

    cma["debit"] = [-float(v) if v != "" else "" for v in cma["debit"] ]

    cma["balance"] = cma["balance"].astype(float)

    cma["category"] = pd.Series(dtype=str, index=cma.index)
    
    cma["type"] = pd.Series(dtype=str, index=cma.index)
        
    cma = cma[["date_dt", "type", "object", "category", "debit", "credit", "balance"]]
    
    for i, row in tqdm(cma.iterrows(), total=cma.shape[0]):
        
        o = row["object"]        
        
        # ADD ":" IN OBJECT COLUMN IF NOT THERE
        reg = re.compile("(Virement interne|Paiement à|Virement SEPA émis vers |Virement SEPA reçu de |Rechargement par carte|Annulation du paiement du .* à|Paiement reçu de)(.*)")
        s = re.search(reg, o)
        if s:
            res = s.group(1) + " : " + s.group(2)
            cma.loc[i, "object"] = res
            o = res
            
        # CHECK IF ALL OBJECTS HAVE ":"
        reg2 = re.compile("(.*)(:\n?)(.*)", flags=re.DOTALL)
        s2 = re.search(reg2, o)
        
        if not s2:            
            print(f"missing ':' at index {i} in {o}")            
        
        # SPLIT OBJECT TO GET TYPE and "from" or "to" value depending on wether the amount is positive or not    
        else:
            cma.loc[i, "type"] = ' '.join(s2.group(1).split())
            
        fromto = ' '.join(s2.group(3).upper().split())
        
        if fromto == "FREE":
            fromto = "FREE HAUTDEBIT" 
        
        reg3 = re.compile("^[0-9]*$")
        s3 = re.search(reg3, fromto)
        if s3:
            fromto = "ATM"
            
        if row["debit"] != "":
            cma.loc[i, "object"] = 'to ' + fromto
        elif row["credit"] != "":
            cma.loc[i, "object"] = 'from ' + fromto
    
    return cma

# %%
cma = process_cma(cma_raw)
# Out:
#   0%|          | 0/2225 [00:00<?, ?it/s]

# %%
def implement_types(cma):
    
    cma_typed = cma.copy()
    
    types_dict = {
        "Annulation": "annul./regul",
        "Régularisation": "annul./regul",
        "Remboursement": "annul./regul",
        "Retrait": "retrait",
        "Transaction": "cb",
        "Paiement à": "cb",
        "Rechargement": "rechargement cb",
        "Virement SEPA émis vers": "virement sortant",
        "Virement SEPA reçu de": "virement entrant",
        "Virement interne": "virement entrant",
        "Paiement reçu de": "virement entrant",
        "Prélèvement automatique": "prélèvement",
    }
    
    for k, v in tqdm(types_dict.items()):
        cma_typed["type"] = np.where(cma_typed["type"].str.contains(k), v, cma_typed["type"])
        
    assert len(cma_typed[cma_typed["type"].isna()]) == 0
    
    return cma_typed

# %%
cma_typed = implement_types(cma)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
froms_dict = {
    "revenu": ["HORUS PHARMA", "STE PHARDEX", "POLE EMPLOI DR IDF"],
    "frais pro": ["PHARDEX"],
    "dette": ["MR OU MME BONNEFOY", "M OU MME BOUVRY CHRISTOPHE", "MME MERCIER CELINE"],
    "intra": ["BONNEFOY JULIEN"],
    "revenu foncier": ["FONCIA AD"],
    "rbt. mutuelle": ["APGIS"],
    "rbt. assurance": ["MMA", "MMA IARD", "AVANSSUR"],
    "cashback": ["CASHBACK LYDIA", "TICKET À GRATTER"],
    "rbt. loc. vehicule": ["EUROPCAR"],
    "rbt. vtc": ["UBER"],
    "rbt. carburant": ["TOTAL"],
    "rbt. elec.": ["MINT ENERGIE"],
    "rbt. fai": ["FREE TELECOM"],
    "rbt. divers": ["MIGUEL FERREIRA", "VANHOUTTE", "REÇU", "KORUM"],
}

# %%
def categorize_froms(cma_typed):
    
    cma_froms = cma_typed.copy()
    
    credits_df = cma_froms[cma_froms["credit"] != ""]

    for i, row in tqdm(credits_df.iterrows(), total=credits_df.shape[0]):
        
        fromm = re.sub("from ", "", row["object"])
        typee = row["type"]
        
        if typee == "annul./regul":
            cma_froms.loc[i, "category"] = "annul/regul"
            
        elif typee == "rechargement cb":
            cma_froms.loc[i, "category"] = "recharge cb"

        for k, v in froms_dict.items():
            for val in v:
                if fromm == val or val in fromm:
                    cma_froms.loc[i, "category"] = k

        
    cma_froms["object"] = cma_froms["object"].fillna('')
            
    return cma_froms

# %%
cma_froms = categorize_froms(cma_typed)
# Out:
#   0%|          | 0/225 [00:00<?, ?it/s]

# %%
tos_dict = {
    "frais bancaires": ["LYDIA"],
    "tabac/fdj": [
        "ALHESA", "LE LONGCHAMP", "LES2STATIONS", "LA CAPE DE FEU", "LE NARVAL", "LE BALTO", "TOPAL", "ARLOME", "LE CIGARIUM", "LE SAINT AUGU", "GL BASTILLE", 
        "LE GALIA", "ROYAL", "LA FRANCAISE DES", "TABAC", "RELAY", "CIVETTE", "FONTENOY", "HAVANE","SUPERMERCAT", "BONAPA", "FENNEC"],
    "courses": ["FRANPRIX", "LIDL", "SIMPLY","CAR CITY KERM", "AUCHAN", "LECLERC", "FRANPRI", "MONOP", "CARR", "PICARD", "SUPERETTE", "MARKET", "MARCHE"],
    "sante": ["DOCTOLIB","PHCIE","PHARM", "MARTI", "PHIE", "ANXO", "APGIS", "MAIER"],
    "cash": ["DISTRIBUTEUR","CREDIT DU NORD","CCM","LA SOCIETE GENERALE", "CIC", "BOULOGNE", "SEVRES", "00013071", "LA BANQUE POSTALE"],
    "equipement": ["MESBAGAGES","SFR","AMAZON","AMZ","BUREAU","LEROY","BRICORAMA","MAISON","BERGER","DARTY","GIFI","PEARL","IKEA","CENTRAK","STORE","TROIFOI","BOULANGER"],
    "digital": ["MEDIUM","HEROKU","H EROKU", "FRANZ","DIGITAL","MICROSOFT","MSFT","APPLE.COM/BILL","JETBRAINS","VPNCOM","UFC","GOOGLE","XMIND","ZENCO", "LINKEDIN"],
    "virement": ["IBAN"],
    "tel. mobile": ["FREE MOBILE"],
    "boulangerie": ["RDT BOULANG","COTE BOULANGE","BOULANGERIE","PETRIN","AUX MERVEILLEUX","BUTTE GLACEE","ECLAIR"],
    "parking/peage" : ["CDG", "SAINT LAZARE", "BAGNEUX", "PAYBYPHON", "GRAND PARIS", "PKG","PEAGE","CMNE DE NEUILLY","RIE DE PARIS","VILLE ","INDIGO","PARKING","SNC PARC","SANEF", "SAGS LOBAU","VINCI"],
    "deplacements" : ["TAXI","UBR","UBER","EUROPCAR","SNCF","EASYJET", "RATP", "UBEEQO", "COFIROUTE"],
    "food/drinks" : ["CHEZ MAX", "DELI", "NICOLE ET LOUIS","SUSHI","HYPOTHESE","PALAIS","CAFE","RENDEZ","QUICK","MOULIN","CANTINA","STARBUCKS","CREPERIE", "GASTRON","MAVROMMATIS","STARB","GELATO","RESTAU","TOOGOOD","SELECTA","MCDONALD","CANAS","PANASIA"],
    "carburant" : ["RELAIS", "GASOPAS","ESTACIO","TOTAL","BP","ARCYCOM"],
    "net/tv" : ["FREE HAUTDEBIT","DISNEY PLUS","CANAL SAT"],
    "frais pro" : ["HOTEL IBIS ACCOR"],
    "electricite" : ["ENERGY", "PLANETE OUI", "MINT"],
    "credit" : ["YOUNITED"],
    "hebergement": ["PREMIERE CLASSE","IBIS STYLES"],
    "assurance" : ["ASSURANCE"],
    "poste" : ["POSTE","CLEFS","PLAQUE","OTYPO"],
    "vanite" : ["LOCCITANE","WECASA","SEPHORA","Levis","OUTLET","COIFF","BARBER"],
    "paiement à" : ["OLIVIER ABBOU","ALEXANDRE CASTRO","MIGUEL FERREIRA"],
    "spectacles" : ["TICKETS","JARDIN ACCLIMAT"],
    "cadeaux" : ["LE POT COMMUN","PLASTIQUES","SWATCH","KADOCOM"],
    "impots/taxes" : ["DRFIP","497304XXXXXX8668000"],
    "post paiement" :  ["POST-PAIEMENT"],
    "cleaner" : ["BUNQ B.V","MULTI GEL","SHOP AND CLEAN"],
    "fdj" : ["FDJ VERSEMENT"],
    "vetements": ["KIABI", "C ET A", "JULES", "LODING","ZARA","LEVIS", "COCORICO"],
    "inconnu": ["SA SUED"],
    "loyer": ["AMMONITIA"],
    "dette perso": ["SYLVIE SANCTORUM"]
}

# %%
def categorize_tos(cma_froms):
    
    cma_tos = cma_froms.copy()
    
    debits_df = cma_tos[cma_tos["debit"] != ""]

    for i, row in tqdm(debits_df.iterrows(), total=debits_df.shape[0]):
        
        too = re.sub("to ", "", row["object"])
        typee = row["type"]

        if typee == "retrait":
            cma_tos.loc[i, "category"] = "cash"
            
        for k, v in tos_dict.items():
            for val in v:
                if too == val or val in too:
                    cma_tos.loc[i, "category"] = k
        
    cma_tos["object"] = cma_tos["object"].fillna('')
                        
    return cma_tos

# %%
cma_tos = categorize_tos(cma_froms)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
def last_cleaning(cma_tos):
    
    cma_cleaned = cma_tos.copy()
    
    for i, row in cma_cleaned[cma_tos['category'].isna()].iterrows():
        cma_cleaned.loc[i, "category"] = "divers"

    categories = list(cma_cleaned["category"].unique())
    categories.sort()

    cma_cleaned["category"] = pd.Categorical(cma_cleaned["category"], categories=categories)

    cma_cleaned=cma_cleaned.sort_values(by="date_dt", ascending=False)

    cma_cleaned.reset_index(drop=True, inplace=True)
    
    return cma_cleaned

# %%
df = last_cleaning(cma_tos)

# %%
 df.to_csv(f"{statement_dir}/csv/compile.csv"   , sep=";", index=False)

# %%
df.to_excel(f"{statement_dir}/xlsx/compile.xlsx", index=False)

# %%
df[df["object"].str.contains("APPLE")]
# Out:
#         date_dt          type               object     category  debit credit  \
# 37   2024-01-22            cb    to APPLE.COM/BILL      digital   2.99
# 143  2023-12-22            cb    to APPLE.COM/BILL      digital   2.99
# 243  2023-11-22            cb    to APPLE.COM/BILL      digital   2.99
# 347  2023-10-22            cb    to APPLE.COM/BILL      digital   2.99
# 430  2023-09-22            cb    to APPLE.COM/BILL      digital   2.99
# 505  2023-08-22            cb    to APPLE.COM/BILL      digital   2.99
# 604  2023-07-22            cb    to APPLE.COM/BILL      digital   2.99
# 703  2023-06-22            cb    to APPLE.COM/BILL      digital   2.99
# 782  2023-05-25            cb    to APPLE.COM/BILL      digital   2.99
# 815  2023-05-04            cb    to APPLE.COM/BILL      digital  12.99
# 841  2023-04-22            cb    to APPLE.COM/BILL      digital   2.99
# 872  2023-04-13            cb    to APPLE.COM/BILL      digital   2.99
# 963  2023-02-22            cb    to APPLE.COM/BILL      digital   2.99
# 1036 2023-01-22            cb    to APPLE.COM/BILL      digital   2.99
# 1083 2022-12-28            cb    to APPLE.COM/BILL      digital   4.99
# 1093 2022-12-24            cb  to APPLE STORE R315   equipement   64.0
# 1114 2022-12-22            cb    to APPLE.COM/BILL      digital   2.99
# 1173 2022-11-22            cb    to APPLE.COM/BILL      digital   2.99
# 1245 2022-10-23            cb    to APPLE.COM/BILL      digital   9.99
# 1247 2022-10-22            cb    to APPLE.COM/BILL      digital   2.99
# 1328 2022-09-23            cb    to APPLE.COM/BILL      digital   9.99
# 1330 2022-09-23            cb    to APPLE.COM/BILL      digital   2.99
# 1398 2022-08-22            cb    to APPLE.COM/BILL      digital   2.99
# 1521 2022-07-23            cb    to APPLE.COM/BILL      digital   9.99
# 1522 2022-07-23            cb    to APPLE.COM/BILL      digital   2.99
# 1610 2022-07-02  annul./regul  from APPLE.COM/BILL  annul/regul         98.99
# 1631 2022-06-29            cb    to APPLE.COM/BILL      digital  79.99
# 1632 2022-06-29            cb    to APPLE.COM/BILL      digital  98.99
# 1670 2022-06-22            cb    to APPLE.COM/BILL      digital   2.99
# 1677 2022-06-20            cb    to APPLE.COM/BILL      digital   9.99
# 1774 2022-05-22            cb    to APPLE.COM/BILL      digital   2.99
# 1852 2022-04-22            cb    to APPLE.COM/BILL      digital   2.99
# 1967 2022-03-26            cb    to APPLE.COM/BILL      digital   2.99
# 1970 2022-03-26            cb    to APPLE.COM/BILL      digital  14.99
# 1995 2022-03-17            cb    to APPLE.COM/BILL      digital  79.99
# 2042 2022-02-23            cb    to APPLE.COM/BILL      digital   2.99
# 2130 2022-01-26            cb    to APPLE.COM/BILL      digital  39.99
# 2143 2022-01-23            cb    to APPLE.COM/BILL      digital   8.99
# 2148 2022-01-22            cb    to APPLE.COM/BILL      digital   2.99
# 2175 2022-01-14            cb    to APPLE.COM/BILL      digital   6.99
# 2209 2022-01-05            cb    to APPLE.COM/BILL      digital  39.99
#
#       balance
# 37      71.20
# 143   2108.51
# 243    393.55
# 347     43.19
# 430      6.22
# 505    263.33
# 604    101.40
# 703     34.10
# 782    927.70
# 815    510.76
# 841     78.16
# 872    742.08
# 963     68.15
# 1036    45.70
# 1083  1637.34
# 1093  1839.68
# 1114   173.72
# 1173     4.08
# 1245   166.30
# 1247   355.72
# 1328  1139.89
# 1330    31.76
# 1398    14.54
# 1521    13.34
# 1522    23.33
# 1610  2870.45
# 1631  3496.07
# 1632  3576.06
# 1670   118.96
# 1677    85.48
# 1774    99.00
# 1852   110.89
# 1967   681.94
# 1970   738.11
# 1995    93.77
# 2042    59.49
# 2130   668.89
# 2143    26.97
# 2148   412.29
# 2175   150.74
# 2209   365.65

# %%
Counter(df["object"]).most_common()
# Out:
# [('to CAR CITY KERM', 293),
#  ('to TABAC PRESSE', 112),
#  ('to LYDIA', 109),
#  ('to FRANPRIX', 82),
#  ('to ATM', 80),
#  ('to AMAZON DIGITA', 64),
#  ('to MONOPRIX', 61),
#  ('to UBR* PENDING.UBER.COM', 60),
#  ('to LA SOCIETE GENERALE', 50),
#  ('to VILLE DE PARIS', 44),
#  ('to APPLE.COM/BILL', 39),
#  ('to LA BANQUE POSTALE', 36),
#  ('to BOULANGERIE THIE', 29),
#  ('from MR OU MME BONNEFOY', 29),
#  ('to FREE MOBILE', 27),
#  ('to JETBRAINS', 25),
#  ('to E.LECLERC', 25),
#  ('to AMAZON PAYMEN', 24),
#  ('from ATM', 24),
#  ('to LE LONGCHAMP', 24),
#  ('to PHARMACIE TRA', 23),
#  ('from MARCHAND NON COMMUNIQUÉ', 21),
#  ('to CIC BOULOGNE RIVES D', 19),
#  ('to DISNEY PLUS', 18),
#  ('from HORUS PHARMA', 16),
#  ('to AUCHAN VELIZY', 15),
#  ('to AMZ DIGITAL F', 15),
#  ('to SITIS MARKET', 15),
#  ('to CARREFOURMARKET', 14),
#  ('from MME MERCIER CELINE', 14),
#  ('from UBR* PENDING.UBER.COM', 13),
#  ('from BONNEFOY JULIEN', 12),
#  ('to SN.NORD* VPNCOM', 12),
#  ('to ALHESA', 12),
#  ('to CARREFOUR', 11),
#  ('to CAR CITY KERMEN', 11),
#  ('from POLE EMPLOI DR IDF', 11),
#  ('to STARBUCKS', 11),
#  ('from M OU MME BOUVRY CHRISTOPHE', 11),
#  ('from SAS FONCIA AD IMMOBILIER', 11),
#  ('from STE PHARDEX', 10),
#  ('to TOTAL', 10),
#  ('to IBAN FR7640618XXXXX20', 10),
#  ('to AMZN MKTP FR', 9),
#  ('to PETRIN RIBEIROU', 9),
#  ('to SNCF', 9),
#  ('to DIRECT ASSURANCE 743141616', 9),
#  ('to MICROSOFT*SUBSCRIPTION', 9),
#  ('to BP TRAPPES ML', 9),
#  ('to MCDONALDS', 9),
#  ('to MIGUEL FERREIRA', 9),
#  ('to IBAN FR7630056XXXXX80', 8),
#  ('to A MEDIUM CORPORATION', 8),
#  ('to COFIROUTE', 8),
#  ('to PHARM REPUBLI', 8),
#  ('to OUI ENERGY SAS 2021-07', 8),
#  ('to SELECTA RFF LYON C', 8),
#  ('to AMAZON.FR', 7),
#  ('to SA SUED', 7),
#  ('to GRAND PARIS SEINE OUEST', 7),
#  ('from TOTAL', 7),
#  ('to PHIE PREMIERE', 7),
#  ('to UBER * PENDING', 7),
#  ('to UBER *TRIP', 6),
#  ('from PHARDEX', 6),
#  ('to APGIS', 6),
#  ('to PEAGE AUTOROUTE ASF', 6),
#  ('to YOUNITED', 6),
#  ('to AMMONITIA', 6),
#  ('to STATTELPAYBYPHON2383691', 6),
#  ('to HOTEL IBIS ACCOR', 5),
#  ('to ARLOME', 5),
#  ('to PHIE RENAULT SC', 5),
#  ('to PANASIA CAP3000', 5),
#  ('to IBAN FR7613507XXXXX07', 4),
#  ('to NATIONALE DISTRI', 4),
#  ('to FREE HAUTDEBIT', 4),
#  ('to VINCI 206517840', 4),
#  ('to BRICORAMA', 4),
#  ('to MARIE DE PARIS', 4),
#  ('to CMNE DE NEUILLY SUR SEINE', 4),
#  ('to POST-PAIEMENT', 4),
#  ('to NYX*LAMAISONLYOVEL', 4),
#  ('to PRODUITS BERGER', 4),
#  ('from APGIS', 4),
#  ('to AMAZON EU SAR', 4),
#  ('to WECASA', 4),
#  ('to IBIS STYLES NFC', 4),
#  ('to RATP', 4),
#  ('to LA POSTE L921050', 3),
#  ('to CARREFOUR EXP', 3),
#  ('to NYX*FDADISTRIBUTION', 3),
#  ('from CASHBACK LYDIA', 3),
#  ('to INDIGO', 3),
#  ('from NYX*LAMAISONLYOVEL', 3),
#  ('to ADEO*LEROY MERLIN', 3),
#  ('to MY MARKET', 3),
#  ('to SC-FRANPRIX', 3),
#  ('to LIDL ST CYR L', 3),
#  ('from AMAZON PAYMENTS 2441535', 3),
#  ('to NICOLE ET LOUIS', 3),
#  ("to LECLERC BOIS D'ARCY", 3),
#  ("to SAINT CYR L'ECO", 3),
#  ('to ZENCO', 3),
#  ('to AMAZON DIGITAL 2948426', 3),
#  ('to IBAN LT1432500XXXXX37', 3),
#  ('from MIGUEL FERREIRA', 3),
#  ('to PHARMACIE TRAPEZE', 2),
#  ('to BOULOGNE', 2),
#  ('to PICARD 1051', 2),
#  ('to TABAC LAM', 2),
#  ('to GOOGLE *DOMAINS', 2),
#  ('to REL.PKG PORTE ST', 2),
#  ("to JAMIE'S DELI", 2),
#  ('to RELAY373951SC', 2),
#  ('to AU PALAIS DES', 2),
#  ('to STARBUCKS 1', 2),
#  ('to SARL PICARD H E', 2),
#  ('to S N B', 2),
#  ('to INDIGO 751614', 2),
#  ('to GIFI', 2),
#  ('from TICKET À GRATTER', 2),
#  ('to AUX MERVEILLEUX', 2),
#  ('to MAAF ASSURANCES', 2),
#  ('to SC.C.3 CLEFS', 2),
#  ('to AUCHAN B2C DRIVE', 2),
#  ('to COTISATION ASSURANCE 178341906', 2),
#  ('to CIC PARIS CONVENTION', 2),
#  ('to ANXO LIONEL', 2),
#  ('to SNC PARC LYONDID', 2),
#  ('to LA POSTE BOUTIQU', 2),
#  ('to ADS SUPERETTE', 2),
#  ('to EUROPCAR.COM/FR', 2),
#  ('to LE BALTO', 2),
#  ('to ASTERIX RESTAU', 2),
#  ('to BAGNEUX VOIRIE', 2),
#  ('to IBAN FR7611315XXXXX44', 2),
#  ('to L ECLAIR D ARCY', 2),
#  ('to J&W CAFE TABAC', 2),
#  ('to TOPAL ENGIN', 2),
#  ('to VILLE MONTIGNY LE BRETONN', 2),
#  ('to BUREAU VALLEE', 2),
#  ('to EDGAR GASTRONOMI', 2),
#  ('to RELAY 373449SC', 2),
#  ('to LA CANTINA DU', 2),
#  ('to EASYJET', 2),
#  ('to UBEEQO SAS', 2),
#  ('to RELAY 324285SC', 2),
#  ('to SELECTA G DE VER', 2),
#  ('to CANAL SAT', 1),
#  ('to AMZ DIGITAL FRA', 1),
#  ('to COCORICO', 1),
#  ('to ELV', 1),
#  ('to MAIRIE DE PARIS', 1),
#  ('to HEROKU* DEC-90630348', 1),
#  ('to SOA', 1),
#  ('to PHARMACIE ARC E', 1),
#  ('to ROKICINSKIMARIU', 1),
#  ('to SARL PLASTIQUES', 1),
#  ('to HEROKU* NOV-89574553', 1),
#  ('to FREE HAUTDEBIT 1247865758', 1),
#  ('from ARCYCOM', 1),
#  ('to ARCYCOM', 1),
#  ('to PINK POUSS', 1),
#  ('to HEROKU* OCT-88407311', 1),
#  ('to ROYAL PEREIRE', 1),
#  ('to ROSETTA', 1),
#  ('to FREE HAUTDEBIT 1240558394', 1),
#  ('to MAISON BERGER PARIS', 1),
#  ('to SUMUP *2THELOO RAILWAY', 1),
#  ('to LOCCITANE', 1),
#  ('to QPF HDV BS', 1),
#  ('to HEROKU* SEP-87825037', 1),
#  ('from FREE TELECOM', 1),
#  ('to FREE HAUTDEBIT 1233282333', 1),
#  ('to BOULANGERIE', 1),
#  ('to INDIGO0751707', 1),
#  ('to LUMIERE', 1),
#  ('to JB AU RENDEZ VOU', 1),
#  ('to LE CENTRAL CAFE', 1),
#  ('to FREE HAUTDEBIT 1226046907', 1),
#  ('to DOCTOLIB* DR AKBAL AZI', 1),
#  ('from DOCTOLIB* DR AKBAL AZI', 1),
#  ('to YOUNITED PAYMENT', 1),
#  ('to PHARMACIE ORL', 1),
#  ('to JARDIN ACCLIMAT', 1),
#  ('to PHIE KERMEN', 1),
#  ('to CAFE DU NORD', 1),
#  ('to LA BUTTE GLACEE', 1),
#  ('from GASOPAS- TERMINALS', 1),
#  ('to GASOPAS- TERMINALS', 1),
#  ('to SUPERMERCAT ALFA', 1),
#  ('to ESTACIO SERVEI PIC BLANC', 1),
#  ('to FREE HAUTDEBIT 1218817103', 1),
#  ('from PHARM REPUBLI', 1),
#  ('to LE SAINT AUGU', 1),
#  ('to INDIGO 921106', 1),
#  ('to MAVROMMATIS', 1),
#  ('to DRFIP ILLE ET VILAINE', 1),
#  ('to PHOTOMATON', 1),
#  ('to IWONALEX', 1),
#  ('to FRANPRIX 4093', 1),
#  ('to FREE HAUTDEBIT 1211660083', 1),
#  ('to MARCHE DE LA', 1),
#  ('to LE GALIA', 1),
#  ('to BP VIRONVAY', 1),
#  ('to FREE HAUTDEBIT 1204493735', 1),
#  ('from ADEO*LEROY MERLIN', 1),
#  ('from LEROY MERLIN FR', 1),
#  ('to LEROY MERLIN FR', 1),
#  ('to SEVRES', 1),
#  ('to AOB SLIMPY', 1),
#  ('to FREE HAUTDEBIT 1197338618', 1),
#  ('to LE ROYAL BOULOG', 1),
#  ('to VAD FRANCE', 1),
#  ('to MICROSOFT#G021766963', 1),
#  ('to MONOP', 1),
#  ('to TABAC VILLAGE', 1),
#  ('to SELECTA SAS', 1),
#  ('to MICROSOFT#G020555794', 1),
#  ('to TOOGOODTOG SVRWCTR7UD4', 1),
#  ('to FREE HAUTDEBIT 1183079928', 1),
#  ('to RELAY 362053SC', 1),
#  ('to TROIFOIRIEN', 1),
#  ('to CARGO CENTRAK', 1),
#  ('to LA FRANCAISE DES', 1),
#  ('to EASYJET EEA FRANCE', 1),
#  ('to TABAC LES 4 ARBR', 1),
#  ('to MICROSOFT#G019503249', 1),
#  ('to DARTY BOLOGNE29', 1),
#  ('to 497304XXXXXX8668000 NON CONF 1 17/01/23 CAR CITY KERMEN', 1),
#  ('to MICROSOFT#G018130305', 1),
#  ('to FREE HAUTDEBIT 1168850042', 1),
#  ('to APPLE STORE R315', 1),
#  ('to THE BARBER COMPA', 1),
#  ('to PICARD SA 347', 1),
#  ('to BUNQ B.V', 1),
#  ('to DOCTEUR MARTI', 1),
#  ('to MICROSOFT#G017280218', 1),
#  ('to FREE HAUTDEBIT 1161825960', 1),
#  ('to 497304XXXXXX8668000 29/10/22 1', 1),
#  ('to MICROSOFT G016072085', 1),
#  ('to FREE HAUTDEBIT 1154791731', 1),
#  ('to 497304XXXXXX8668000 29/09/22 1', 1),
#  ('to SANEF', 1),
#  ('to AUCHAN RONCQ', 1),
#  ('from MMA IARD', 1),
#  ('to CANDY COIFFURE', 1),
#  ('to IKEA', 1),
#  ('to PHARMACIE GIRAUD', 1),
#  ('to MICROSOFT G015110432', 1),
#  ('from AVANSSUR', 1),
#  ('to LE POT COMMUN', 1),
#  ('to LE CIGARIUM', 1),
#  ('to CARREFEXPRESSSCO', 1),
#  ('to XMIND LTD.', 1),
#  ('to KIOSQUE STARB', 1),
#  ('to FREE HAUTDEBIT 1147765244', 1),
#  ('to SISI', 1),
#  ('to ESPACE TABAC 50', 1),
#  ('to 497304XXXXXX8668000 29/08/22 1', 1),
#  ('to MK MOUCHOTTE', 1),
#  ('to MICROSOFT G014088730', 1),
#  ('to TICKETS WEEZEVENT', 1),
#  ('from EUROPCAR PARC06 PARIS', 1),
#  ('to PARKING CARNOT', 1),
#  ('to FREE HAUTDEBIT 1140765877', 1),
#  ('to LE NARVAL', 1),
#  ('to OTYPO', 1),
#  ('to EUROPCAR PARC06 PARIS', 1),
#  ('to 497304XXXXXX8668000 29/07/22 1', 1),
#  ('to DR MAIER', 1),
#  ('to CARREFOUR MARKET', 1),
#  ('to KAYANI RESTAURAN', 1),
#  ('to GELATO JUNKIE', 1),
#  ('to BP MARSEILLE', 1),
#  ('to MICROSOFT G013379150', 1),
#  ('to GL BASTILLE', 1),
#  ('to GLOUTLET ONP', 1),
#  ('to LEVIS FRANCE - PARIS OLS', 1),
#  ('to SEPHORA 136', 1),
#  ('from EUROPCAR PARW01 VERSAILLE', 1),
#  ('to OLIVIER ABBOU', 1),
#  ('to PLAQUE RAPIDE', 1),
#  ('to EUROPCAR PARW01 VERSAILLE', 1),
#  ('to FREE HAUTDEBIT 1136655680', 1),
#  ('to PEARL DIFFUSION', 1),
#  ('to BOULANGERIE DAUTEUIL', 1),
#  ('to UFC QUE CHOISIR', 1),
#  ('to ALEXANDRE CASTRO', 1),
#  ('to IBAN FR7618206XXXXX48', 1),
#  ('from WECASA', 1),
#  ('to 497304XXXXXX8668000 29/06/22 1', 1),
#  ('to MICROSOFT G012311586', 1),
#  ('to MONOPRIX 4653134', 1),
#  ('to IBAN FR7616798XXXXX56', 1),
#  ('to STATION TOTAL', 1),
#  ("to RELAIS EPI D'OR", 1),
#  ('to SUSHI GROUPE', 1),
#  ('to JULES', 1),
#  ('to BOULANGER', 1),
#  ('to LA CAPE DE FEU', 1),
#  ('to TABAC GLAB', 1),
#  ('to COTE BOULANGE', 1),
#  ('to IBAN FR7630066XXXXX32', 1),
#  ('to FREE HAUTDEBIT 1129580086', 1),
#  ('to BP PARIS MONT', 1),
#  ('to SHOP AND CLEAN B.V.', 1),
#  ('to CGF15868PAULK2', 1),
#  ('from APPLE.COM/BILL', 1),
#  ('to LODING', 1),
#  ('to ZARA HAUSSMANN', 1),
#  ('to CC SAINT LAZARE', 1),
#  ('to FRANPRIX 4222', 1),
#  ('to SAMSONITE STORE PARIS', 1),
#  ('to FRANPRIX 8315', 1),
#  ('to TABAC MON ANGE', 1),
#  ('to L HYPOTHESE', 1),
#  ('to LINKEDIN LINKEDIN 7965814674', 1),
#  ('to MICROSOFT G011382346', 1),
#  ('to CARREFOUR ISS', 1),
#  ('to FRANPRIX 5028', 1),
#  ('from MINT ENERGIE', 1),
#  ('to LA POSTE L785450', 1),
#  ('to ESPACE SFR', 1),
#  ('to FREE HAUTDEBIT 1122681091', 1),
#  ('to MESBAGAGES.CO', 1),
#  ('to KADOCOM', 1),
#  ('to SWATCH', 1),
#  ('to SC-ROYAL CAMBRO', 1),
#  ('to 134 RDT BOULANG', 1),
#  ('to LINKEDIN LINKEDIN 7868576644', 1),
#  ('to MICROSOFT G010870650', 1),
#  ('to BP SEVRES', 1),
#  ('to QUICK', 1),
#  ('to TABACECLAIRDARCY', 1),
#  ('to FREE HAUTDEBIT 1115704713', 1),
#  ('to E L BOULOGNE', 1),
#  ('to SARL LODING', 1),
#  ('to PARIS EXELMANS', 1),
#  ('to MOULIN D AUTEUIL', 1),
#  ('to CREPERIE BOUFFAY', 1),
#  ('to RELAY 341206SC', 1),
#  ('to MSFT *<E0500IDQF6>', 1),
#  ('to SC-LES2STATIONS', 1),
#  ('to CIVETTE D AUT', 1),
#  ('to ASCODEV CDG', 1),
#  ('to LINKEDIN LINKEDIN 6836454646', 1),
#  ('to CREDIT DU NORD', 1),
#  ('to MICROSOFT G009886198', 1),
#  ('to PHARMACIE CAP', 1),
#  ('to RELAY 362079SC', 1),
#  ('to CHEZ MAX', 1),
#  ('to PETIT FENNEC', 1),
#  ('to ALRO', 1),
#  ('to SC MCDONALD S', 1),
#  ('from JULES 0600', 1),
#  ('to TAXI BANLIEUE', 1),
#  ('to CANAS Y TAPAS', 1),
#  ('from MMA IARD SA', 1),
#  ('to FREE HAUTDEBIT 1108752846', 1),
#  ('to RELAY 362061SC', 1),
#  ('to BUY PARIS DUTY', 1),
#  ('to RELAY362160SC', 1),
#  ('to JULES 0600', 1),
#  ('to C ET A FRANCE', 1),
#  ('to KIABI PSC', 1),
#  ('to LE HAVANE', 1),
#  ('from UBER * PENDING', 1),
#  ('to MULTI GEL REMOVER', 1),
#  ('to FRANZ / MEETFRANZ', 1),
#  ('to LE FONTENOY', 1),
#  ('to MSFT *<E0500I0VQV>', 1),
#  ('to MINT', 1),
#  ('to PICARD 0469', 1),
#  ('to LINKEDIN LINKEDIN 6740501036', 1),
#  ('from KORUM', 1),
#  ('from VANHOUTTE', 1),
#  ('to FREE HAUTDEBIT 1101806266', 1),
#  ('to MSFT * E0500HNR6X', 1),
#  ('to SC-S E I P DIST', 1),
#  ('to PREMIERE CLASSE', 1),
#  ('to PHCIE CC LECL', 1),
#  ("to CCM SAINT CYR L'ECOL", 1),
#  ('to DIRECTASSURANCE', 1),
#  ('to UMEN MEDICAL', 1),
#  ('to VELOCIVETTE', 1),
#  ('from UBEEQO SAS', 1),
#  ('to SAGS LOBAU', 1),
#  ('to DARTY IDF', 1),
#  ('to BP PARIS', 1),
#  ('to FRANPRIX 5486', 1),
#  ('to MSFT *<E0500HAUU8>', 1),
#  ('to FDJ VERSEMENT', 1),
#  ('from FONCIA AD IMMOBILIER GERANCE', 1),
#  ('to PLANETE OUI', 1),
#  ('to DUFOUR BONAPA', 1),
#  ('to MCDONALDS 69', 1),
#  ('to LA POSTE 755000', 1),
#  ('from REÇU', 1)]

# %%
def from_pdfs_to_csv(statement_dir):
    
    statements = [f"{statement_dir}/{f}" for f in listdir(statement_dir) if isfile(join(statement_dir, f))]
    statements.sort()
    
    cma_raw = process_statement_dir(statements)
    cma = process_cma(cma_raw)
    
    clear_output()

    print("TYPES")
    cma_typed = implement_types(cma)
    
    print("CATEGORIES & FROM/TO")
    cma_froms = categorize_froms(cma_typed)    
    cma_tos = categorize_tos(cma_froms)

    cma_cleaned = last_cleaning(cma_tos)
    cma_cleaned = cma_cleaned[ordered_cols]
    
    csv_fn = f"{statement_dir}/csv/compile.csv"
    
    cma_cleaned.to_csv(csv_fn, sep=";", index=False)
        
    return None

# %%
jan = pd.read_excel("../../application/data/statements/xlsx/bankstatement202401.xlsx")
jan.columns=["date_df", "object"]
for col in ["category", "credit", "debit"]:
    jan[col] = pd.Series(dtype=object, index=jan.index)

# %%
reg = re.compile("([+\-]\s?[0-9]*,[0-9]{2}\s€)(.*)")

# %%
for i, row in jan.iterrows():
    
    o = row["object"]
    s = re.search(reg,o)
    
    if s:
        amount = re.sub(' ', '', s.group(1))
        amount = re.sub('€', '', amount)
        amount = re.sub(",", ".", amount)
        
        if amount[0] == "-":
            amount = re.sub("\-", "", amount)
            jan.loc[i, "debit"] =  float(amount)
            reg2 = re.compile("(.*)( À|AU|à )(.*)")
            s2 = re.search(reg2, o)
            if s2:
                jan.loc[i, "object"] = f"to {s2.group(3)}"
                
            for k, v in tos_dict.items():
                for val in v:
                    if re.sub('to ', '', o) == val or val in re.sub('to ', '', o):
                        jan.loc[i, "category"] = k
                    
                      

        if amount[0] == "+":        
            amount = re.sub("\+", "", amount)
            jan.loc[i, "credit"] =  float(amount)
            reg3 = re.compile("(.*)( DE )(.*)")
            s3 = re.search(reg3, o)
            if s3:
                jan.loc[i, "object"] = f"from {s3.group(3)}"
                
            for k, v in froms_dict.items():
                for val in v:
                    if re.sub('from ', '', o) == val or val in re.sub('from ', '', o):
                        jan.loc[i, "category"] = k
                        
jan["category"] = jan["category"].fillna("")
                        
for i, row in jan.iterrows():
    if row["category"] == "":
        jan.loc[i, "category"] = "divers"
    
jan.loc[67, "object"] = "to FREE HAUTDEBIT"
jan.loc[67, "category"] = "net/tv"

# %%
 jan[jan["category"].isna()]

# %%
def add_statement(statement_path, statement_dir):
    
    csv_fn = f"{statement_dir}/csv/compile.csv"
    
    db = pd.read_csv(csv_fn, sep=";")
    
    months = list(db["year_mth"].unique())
    months.sort()
    
    month, yr_mth = process_statement(statement_path)
    
    if yr_mth.strftime('%Y %m') in months:
        
        print("data already in csv file")
        
    else:
        
        month["year_mth"] = [f'{yr_mth.strftime("%Y")} {yr_mth.strftime("%m")}' for i in range(month.shape[0])]
        
        month_raw = process_cma(month)
        clear_output()

        print("TYPES")
        month_typed = implement_types(month_raw)
        clear_output()

        print("CATEGORIES & FROM/TO")
        month_froms = categorize_froms(month_typed)
        clear_output()

        month_tos = categorize_tos(month_froms)
        clear_output()

        month_cleaned = last_cleaning(month_tos)
        month_cleaned = month_cleaned[ordered_cols]
        
        db = pd.concat([month_cleaned, db], ignore_index=True)        

        db.to_csv(csv_fn, sep=";", index=False)

        print(f"statements pdfs of {yr_mth.strftime('%B %Y')} added to db")
        
    return None

next_month = "202401"
month_to_add = f"../../application/statements/bankstatement{next_month}.pdf"
add_statement(july, statement_dir)

del db
db = pd.read_csv(csv_fn, sep=";", keep_default_na=False, parse_dates=["date_dt"], dayfirst=True)
db.sample()

# %%
def pivot_cat_by_months(df):    
    return pd.pivot_table(df, index="year_mth", columns="category", values="amount", aggfunc=sum, dropna=False, fill_value=0, margins=True).T

# %%
pivot_cat_by_months = pivot_cat_by_months(db)
pivot_cat_by_months

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
pos = db[db["amount"]>0].sort_values(by="date_dt")
neg = db[db["amount"]<0].sort_values(by="date_dt")

fig = go.Figure()
fig.add_trace(go.Histogram(x=pos["year_mth"], y=pos["amount"], histfunc="sum", name="in"));
fig.add_trace(go.Histogram(x=neg["year_mth"], y=-neg["amount"], histfunc="sum", name="in"));
fig.update_layout(legend = dict(orientation = "h", xanchor = "center", x = 0.5));

# %%
fig.show()

# %%
from PIL import Image 
from pytesseract import pytesseract

# %%
  
# Defining paths to tesseract.exe 
# and the image we would be using 
path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
image_path = r"csv\sample_text.png"
  
# Opening the image & storing it in an image object 
img = Image.open(image_path) 
  
# Providing the tesseract executable 
# location to pytesseract library 
pytesseract.tesseract_cmd = path_to_tesseract 
  
# Passing the image object to image_to_string() function 
# This function will extract the text from the image 
text = pytesseract.image_to_string(img) 
  
# Displaying the extracted text 
print(text[:-1])
